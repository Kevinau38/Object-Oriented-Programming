# %% [markdown]
# <strong><h1>ÔN TẬP FINAL</h1><strong>
#
# <p>PHẦN LÝ THUYẾT</p>
#
# <p> Câu 1: Kỹ thuật kế thừa trong Java  </p>
#
# <p> a. Kế thừa trong Java là gì? Lợi ích của việc sử dụng kế thừa?</p>
#
# <p> - Kế thừa là cơ chế cho phép lớp con sử dụng lại thuộc tính và phương thức của lớp cha.
#
# <br>- Lợi ích là giảm lặp mã, tái sử dụng mã, dễ bảo trì và mở rộng chương trình.</p>
#
# <p> b. Java có hỗ trợ đa kế thừa không? Vì sao?</p>
#
# <p> - Java không hỗ trợ đa kế thừa với class để tránh mơ hồ trong kế thừa phương thức.
#
# <br>- Thay vào đó Java sử dụng interface để hỗ trợ đa kế thừa logic.</p>
#
# <p> c. Làm thế nào để lớp con kế thừa lớp cha? Viết cú pháp và ví dụ ngắn. </p>
#
# <p> - Sử dụng từ khóa extends.
#
# <br> <img src="Images/1.png">
#
# </p>
#
# <p> d. Giải thích từ khóa super trong kế thừa, cho ví dụ sử dụng super.</p>
#
# <p> - Dùng để gọi constructor hoặc phương thức lớp cha.
#
# <br> <img src="Images/2.png">
#
# </p>
#
# <p> Bài Tập code:
#
# <br> Viết 1 đoạn code trong đó lớp Student kế thừa từ lớp Person và sử dụng từ khóa super trong constructor.
#
# <br> <img src="Images/3.png">
#
# <br> <img src="Images/4.png">
#
# </p>
#
# <p> Câu 2: Kỹ thuật Overriding & Overloading </p>
#
# <p> a. Overriding là gì? Khi nào sử dụng Overriding? </p>
#
# <p> - Overriding là ghi đè phương thức lớp cha trong lớp con để thay đổi hành vi.
#
# <br> - Dùng Overriding khi lớp con định nghĩa lại một phương thức đã có trong lớp cha để thay đổi hoặc mở rộng hành vi của nó.
#
# </p>
#
# <p> b. Overloading là gì? Phân biệt Overriding và Overloading. </p>
#
# <p> - Overloading là khi cần nhiều phiên bản của cùng một phương thức với các tham số khác nhau.
#
# <br> - Phân biệt Overriding và Overloading:
#
# <br> + Overriding dùng khi ghi đè phương thức lớp cha trong lớp con.
#
# <br> + Overloading dùng khi nhiều phương thức cùng tên trong 1 lớp.
#
# </p>
#
# <p> c. Cho ví dụ một lớp có cả phương thức overloaded và overridden </p>
#
# <p> <img src="Images/5.png"> </p>
#
# <p> d. Khi override phương thức, tại sao nên sử dụng annotation @Override? </p>
#
# <p> annotaton @Override sử dụng giúp trình biên dịch kiểm tra đúng override, tránh lỗi chính tả hoặc sai tham số.
#
# <br> <img src="Images/6.png">
#
# </p>
#
# <p> Bài Tập code:
#
# <br> Viết lớp Shape với phương thức area(), lớp Rectangle kế thừa Shape và override phương thức area(). </p>
#
# <p> <img src = "Images/8.png"></p>
#
# <p> <img src = "Images/9.1.png"></p>
#
# <p> Câu 3: Đa hình trong kế thừa</p>
#
# <p> a. Đa hình (polymorphism) là gì? </p>
#
# <p> -Là một phương thức có nhiều trạng thái khác nhau, đa dạng bao gồm:
#
# <br> - Override : Ghi đè phương thức lớp cha trong lớp con.
#
# <br> - Overload : Cùng một phương thức có nhiều trạng thái mà khác tham số, khác kiểu dữ liệu. </p>
#
# <p> b. Trình bày ví dụ về đa hình thông qua kế thừa.</p>
#
# <p><img src="Images/7.png"></p>
#
# <p> c. Làm sao để khai thác đa hình thông qua biến tham chiếu của lớp cha? </p>
#
# <p> Trong Java, ta có thể sử dụng biến tham chiếu của lớp cha để gọi phương thức của
# lớp con. Điều này cho phép chương trình hoạt động một cách tổng quát mà không
# cần biết trước lớp con cụ thể. </p>
#
# <p> d. Nêu lợi ích của đa hình đối với việc mở rộng chương trình. </p>
#
# <p> 1. Giúp mã nguồn linh hoạt: Cho phép xử lý các đối tượng theo cách tổng
# quát, thay vì phải biết chính xác từng loại đối tượng.
#
# <br> 2. Dễ dàng mở rộng hệ thống: Khi thêm một lớp mới, chỉ cần kế thừa từ lớp
# cha và ghi đè phương thức, không cần chỉnh sửa mã cũ.
#
# <br> 3. Hỗ trợ nguyên tắc "Open/Closed" trong thiết kế phần mềm: Chương trình
# có thể mở rộng nhưng không cần thay đổi mã hiện có.
#
# <br> 4. Tăng cường tính dễ bảo trì: Khi cần cập nhật hành vi, chỉ cần sửa ở lớp
# con mà không ảnh hưởng đến các phần khác của hệ thống. </p>
#
# <p> Bài Tập code:
#
# <br> Tạo mảng gồm nhiều đối tượng Shape (có các lớp con như Circle, Rectangle). Viết code cho phép gọi phương thức area() trên từng phần tử và in kết quả. </p>
#
# <p><img src="Images/10.png"></p>
#
# <p>
